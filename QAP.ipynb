# %%
import json
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.linear_model import LinearRegression

# %%
dataset_path = './dataset/git_web_ml'
os.listdir(dataset_path)
# Out:
# ['musae_git_edges.csv',
#  'citing.txt',
#  'pruned_df.csv',
#  'README.txt',
#  'features.csv',
#  'musae_git_features.json',
#  'musae_git_target.csv']

# %%
nodes = pd.read_csv(os.path.join(dataset_path, 'musae_git_target.csv'))
nodes
# Out:
#           id            name  ml_target
# 0          0          Eiryyy          0
# 1          1      shawflying          0
# 2          2     JpMCarrilho          1
# 3          3       SuhwanCha          0
# 4          4    sunilangadi2          1
# ...      ...             ...        ...
# 37695  37695  shawnwanderson          1
# 37696  37696       kris-ipeh          0
# 37697  37697        qpautrat          0
# 37698  37698        Injabie3          1
# 37699  37699   caseycavanagh          0
#
# [37700 rows x 3 columns]

# %%
edges = pd.read_csv(os.path.join(dataset_path, 'musae_git_edges.csv'))
edges
# Out:
#          id_1   id_2
# 0           0  23977
# 1           1  34526
# 2           1   2370
# 3           1  14683
# 4           1  29982
# ...       ...    ...
# 288998  37527  37596
# 288999  37529  37601
# 289000  37644   2347
# 289001  25879   2347
# 289002  25616   2347
#
# [289003 rows x 2 columns]

# %%
coeffs = []

# %%
def QAP_linear_regression(nodes, edges, n_rounds):

    coeffs = []

    for i in tqdm(range(n_rounds)):
        ids = np.array(nodes['id']).copy()
        np.random.shuffle(ids)
        nodes['replace_id'] = ids
        replace_mat = np.array(nodes[['id', 'replace_id']])
        replacement = dict()
        for row in replace_mat:
            replacement[row[0]] = row[1]
        temp_edges = edges.copy()
        temp_edges = temp_edges.replace(replacement)  
        temp_edges = temp_edges.merge(nodes[['id', 'ml_target']], how='left', left_on='id_1', right_on='id')
        temp_edges = temp_edges.merge(nodes[['id', 'ml_target']], how='left', left_on='id_2', right_on='id', suffixes=[None, '_2']) 
        test_df = temp_edges.groupby('id_1').mean()[['ml_target', 'ml_target_2']] 
        ml_target = np.array(test_df['ml_target']).reshape((-1, 1))
        ml_target2_mean = test_df['ml_target_2']
        lr = LinearRegression().fit(ml_target, ml_target2_mean)
        coef = lr.coef_[0]
        coeffs.append(coef)

        mean_coef = np.mean(coeffs)
        std_coef = np.std(coeffs)
    
    return mean_coef, std_coef, coeffs

# %%
mean_coef, std_coef, coeffs = QAP_linear_regression(nodes, edges, n_rounds=20)
# Out:
#  70%|███████   | 14/20 [10:09<04:21, 43.54s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/pattanantarangsi/Desktop/Analysis_of_social_networks/Project/QAP.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/pattanantarangsi/Desktop/Analysis_of_social_networks/Project/QAP.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> mean_coef, std_coef, coeffs = QAP_linear_regression(nodes, edges, n_rounds=20)
#
# /Users/pattanantarangsi/Desktop/Analysis_of_social_networks/Project/QAP.ipynb Cell 7 in QAP_linear_regression(nodes, edges, n_rounds)
#      <a href='vscode-notebook-cell:/Users/pattanantarangsi/Desktop/Analysis_of_social_networks/Project/QAP.ipynb#X44sZmlsZQ%3D%3D?line=11'>12</a>     replacement[row[0]] = row[1]
#      <a href='vscode-notebook-cell:/Users/pattanantarangsi/Desktop/Analysis_of_social_networks/Project/QAP.ipynb#X44sZmlsZQ%3D%3D?line=12'>13</a> temp_edges = edges.copy()
# ---> <a href='vscode-notebook-cell:/Users/pattanantarangsi/Desktop/Analysis_of_social_networks/Project/QAP.ipynb#X44sZmlsZQ%3D%3D?line=13'>14</a> temp_edges = temp_edges.replace(replacement)
#      <a href='vscode-notebook-cell:/Users/pattanantarangsi/Desktop/Analysis_of_social_networks/Project/QAP.ipynb#X44sZmlsZQ%3D%3D?line=14'>15</a> temp_edges = temp_edges.merge(nodes[['id', 'ml_target']], how='left', left_on='id_1', right_on='id')
#      <a href='vscode-notebook-cell:/Users/pattanantarangsi/Desktop/Analysis_of_social_networks/Project/QAP.ipynb#X44sZmlsZQ%3D%3D?line=15'>16</a> temp_edges = temp_edges.merge(nodes[['id', 'ml_target']], how='left', left_on='id_2', right_on='id', suffixes=[None, '_2'])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/speech_env/lib/python3.10/site-packages/pandas/core/frame.py:5282, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    5272 @doc(NDFrame.replace, **_shared_doc_kwargs)
#    5273 def replace(
#    5274     self,
#    (...)
#    5280     method: str | lib.NoDefault = lib.no_default,
#    5281 ):
# -> 5282     return super().replace(
#    5283         to_replace=to_replace,
#    5284         value=value,
#    5285         inplace=inplace,
#    5286         limit=limit,
#    5287         regex=regex,
#    5288         method=method,
#    5289     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/speech_env/lib/python3.10/site-packages/pandas/core/generic.py:6655, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    6652     else:
#    6653         to_replace, value = keys, values
# -> 6655     return self.replace(
#    6656         to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6657     )
#    6658 else:
#    6659
#    6660     # need a non-zero len on all axes
#    6661     if not self.size:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/speech_env/lib/python3.10/site-packages/pandas/core/frame.py:5282, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    5272 @doc(NDFrame.replace, **_shared_doc_kwargs)
#    5273 def replace(
#    5274     self,
#    (...)
#    5280     method: str | lib.NoDefault = lib.no_default,
#    5281 ):
# -> 5282     return super().replace(
#    5283         to_replace=to_replace,
#    5284         value=value,
#    5285         inplace=inplace,
#    5286         limit=limit,
#    5287         regex=regex,
#    5288         method=method,
#    5289     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/speech_env/lib/python3.10/site-packages/pandas/core/generic.py:6704, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    6699     if len(to_replace) != len(value):
#    6700         raise ValueError(
#    6701             f"Replacement lists must match in length. "
#    6702             f"Expecting {len(to_replace)} got {len(value)} "
#    6703         )
# -> 6704     new_data = self._mgr.replace_list(
#    6705         src_list=to_replace,
#    6706         dest_list=value,
#    6707         inplace=inplace,
#    6708         regex=regex,
#    6709     )
#    6711 elif to_replace is None:
#    6712     if not (
#    6713         is_re_compilable(regex)
#    6714         or is_list_like(regex)
#    6715         or is_dict_like(regex)
#    6716     ):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/speech_env/lib/python3.10/site-packages/pandas/core/internals/managers.py:458, in BaseBlockManager.replace_list(self, src_list, dest_list, inplace, regex)
#     455 """do a list replace"""
#     456 inplace = validate_bool_kwarg(inplace, "inplace")
# --> 458 bm = self.apply(
#     459     "replace_list",
#     460     src_list=src_list,
#     461     dest_list=dest_list,
#     462     inplace=inplace,
#     463     regex=regex,
#     464 )
#     465 bm._consolidate_inplace()
#     466 return bm
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/speech_env/lib/python3.10/site-packages/pandas/core/internals/managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/speech_env/lib/python3.10/site-packages/pandas/core/internals/blocks.py:799, in Block.replace_list(self, src_list, dest_list, inplace, regex)
#     793     masks = [
#     794         compare_or_regex_search(values, s[0], regex=regex, mask=mask)
#     795         for s in pairs
#     796     ]
#     797 else:
#     798     # GH#38086 faster if we know we dont need to check for regex
# --> 799     masks = [missing.mask_missing(values, s[0]) for s in pairs]
#     801 # error: Argument 1 to "extract_bool_array" has incompatible type
#     802 # "Union[ExtensionArray, ndarray, bool]"; expected "Union[ExtensionArray,
#     803 # ndarray]"
#     804 masks = [extract_bool_array(x) for x in masks]  # type: ignore[arg-type]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/speech_env/lib/python3.10/site-packages/pandas/core/internals/blocks.py:799, in <listcomp>(.0)
#     793     masks = [
#     794         compare_or_regex_search(values, s[0], regex=regex, mask=mask)
#     795         for s in pairs
#     796     ]
#     797 else:
#     798     # GH#38086 faster if we know we dont need to check for regex
# --> 799     masks = [missing.mask_missing(values, s[0]) for s in pairs]
#     801 # error: Argument 1 to "extract_bool_array" has incompatible type
#     802 # "Union[ExtensionArray, ndarray, bool]"; expected "Union[ExtensionArray,
#     803 # ndarray]"
#     804 masks = [extract_bool_array(x) for x in masks]  # type: ignore[arg-type]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/speech_env/lib/python3.10/site-packages/pandas/core/missing.py:99, in mask_missing(arr, values_to_mask)
#      96         if not isinstance(new_mask, np.ndarray):
#      97             # usually BooleanArray
#      98             new_mask = new_mask.to_numpy(dtype=bool, na_value=False)
# ---> 99         mask |= new_mask
#     101 if na_mask.any():
#     102     mask |= isna(arr)
#
# KeyboardInterrupt:

# %%
mean_coef
# Out:
# 0.0010409176955971332

# %%
coeffs
# Out:
# [0.004004838096268154,
#  0.00382815013870159,
#  0.004914137604000279,
#  -0.00459624657213348,
#  -0.0029462907888508764]

# %%
std_coef
# Out:
# 0.003980722893447656

# %%
import scipy
z_score = 307.5567491
scipy.stats.norm.sf(abs(z_score))*2
# Out:
# 4.599930578470714e-205

# %%
temp_edges = edges.copy()
temp_edges = temp_edges.merge(nodes[['id', 'ml_target']], how='left', left_on='id_1', right_on='id')
temp_edges = temp_edges.merge(nodes[['id', 'ml_target']], how='left', left_on='id_2', right_on='id', suffixes=[None, '_2']) 
test_df = temp_edges.groupby('id_1').mean()[['ml_target', 'ml_target_2']] 
ml_target = np.array(test_df['ml_target']).reshape((-1, 1))
ml_target2_mean = test_df['ml_target_2']
lr = LinearRegression().fit(ml_target, ml_target2_mean)
coef = lr.coef_[0]

# %%
coef
# Out:
# 0.3881983092000647

# %%
ids = np.array(nodes['id']).copy()
np.random.shuffle(ids)
nodes['replace_id'] = ids

# %%
nodes
# Out:
#           id            name  ml_target  replace_id
# 0          0          Eiryyy          0       18176
# 1          1      shawflying          0       25398
# 2          2     JpMCarrilho          1       32588
# 3          3       SuhwanCha          0       13988
# 4          4    sunilangadi2          1       27555
# ...      ...             ...        ...         ...
# 37695  37695  shawnwanderson          1       20065
# 37696  37696       kris-ipeh          0       20738
# 37697  37697        qpautrat          0       22457
# 37698  37698        Injabie3          1       18071
# 37699  37699   caseycavanagh          0        2112
#
# [37700 rows x 4 columns]

# %%
replace_mat = np.array(nodes[['id', 'replace_id']])

# %%
replacement = dict()
for row in replace_mat:
    replacement[row[0]] = row[1]

# %%
temp_edges = edges.copy()
temp_edges = temp_edges.replace(replacement)

# %%
temp_edges
# Out:
#          id_1   id_2
# 0        6433   4169
# 1       26553  14971
# 2       26553  35434
# 3       26553  12617
# 4       26553  34061
# ...       ...    ...
# 288998   5477  33511
# 288999   6596  21294
# 289000  35899   7360
# 289001  20289   7360
# 289002  13938   7360
#
# [289003 rows x 2 columns]

# %%
nodes
# Out:
#           id            name  ml_target  replace_id
# 0          0          Eiryyy          0        6433
# 1          1      shawflying          0       26553
# 2          2     JpMCarrilho          1       30541
# 3          3       SuhwanCha          0        3195
# 4          4    sunilangadi2          1       36748
# ...      ...             ...        ...         ...
# 37695  37695  shawnwanderson          1        9041
# 37696  37696       kris-ipeh          0       12668
# 37697  37697        qpautrat          0        4893
# 37698  37698        Injabie3          1       34588
# 37699  37699   caseycavanagh          0       17728
#
# [37700 rows x 4 columns]

# %%
edges
# Out:
#          id_1   id_2
# 0           0  23977
# 1           1  34526
# 2           1   2370
# 3           1  14683
# 4           1  29982
# ...       ...    ...
# 288998  37527  37596
# 288999  37529  37601
# 289000  37644   2347
# 289001  25879   2347
# 289002  25616   2347
#
# [289003 rows x 2 columns]

# %%
temp_edges = temp_edges.merge(nodes[['id', 'ml_target']], how='left', left_on='id_1', right_on='id')
temp_edges = temp_edges.merge(nodes[['id', 'ml_target']], how='left', left_on='id_2', right_on='id', suffixes=[None, '_2'])

# %%
temp_edges
# Out:
#          id_1   id_2     id  ml_target   id_2  ml_target_2
# 0        6433   4169   6433          0   4169            0
# 1       26553  14971  26553          0  14971            0
# 2       26553  35434  26553          0  35434            0
# 3       26553  12617  26553          0  12617            0
# 4       26553  34061  26553          0  34061            0
# ...       ...    ...    ...        ...    ...          ...
# 288998   5477  33511   5477          0  33511            0
# 288999   6596  21294   6596          0  21294            0
# 289000  35899   7360  35899          1   7360            0
# 289001  20289   7360  20289          0   7360            0
# 289002  13938   7360  13938          0   7360            0
#
# [289003 rows x 6 columns]

# %%
test_df = temp_edges.groupby('id_1').mean()[['ml_target', 'ml_target_2']]
test_df
# Out:
#        ml_target  ml_target_2
# id_1
# 0            0.0     0.000000
# 1            0.0     0.000000
# 2            1.0     1.000000
# 3            0.0     0.000000
# 4            1.0     1.000000
# ...          ...          ...
# 37693        1.0     0.333333
# 37694        0.0     0.000000
# 37697        0.0     0.153846
# 37698        1.0     0.285714
# 37699        0.0     0.000000
#
# [30855 rows x 2 columns]

# %%
ml_target = np.array(test_df['ml_target']).reshape((-1, 1))
ml_target2_mean = test_df['ml_target_2']

# %%
lr = LinearRegression().fit(ml_target, ml_target2_mean)
lr.coef_[0]
# Out:
# 0.000509603049221263

# %%
np.array(edges)
# Out:
# array([[    0, 23977],
#        [    1, 34526],
#        [    1,  2370],
#        ...,
#        [37644,  2347],
#        [25879,  2347],
#        [25616,  2347]])

# %%
edges
# Out:
#          id_1   id_2
# 0           0  23977
# 1           1  34526
# 2           1   2370
# 3           1  14683
# 4           1  29982
# ...       ...    ...
# 288998  37527  37596
# 288999  37529  37601
# 289000  37644   2347
# 289001  25879   2347
# 289002  25616   2347
#
# [289003 rows x 2 columns]

# %%
def replace_id(id):
    return nodes[nodes['id']==id]['replace_id']


edges['id_1_new'] = edges['id_1'].apply(lambda x: replace_id(x))
edges['id_2_new'] = edges['id_2'].apply(lambda x: replace_id(x))
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
ids[:10]
# Out:
# array([23153, 12985, 23833, 15664, 15274, 24363,  6029, 13330,  4126,
#        31885])

# %%
nodes
# Out:
#           id            name  ml_target
# 0          0          Eiryyy          0
# 1          1      shawflying          0
# 2          2     JpMCarrilho          1
# 3          3       SuhwanCha          0
# 4          4    sunilangadi2          1
# ...      ...             ...        ...
# 37695  37695  shawnwanderson          1
# 37696  37696       kris-ipeh          0
# 37697  37697        qpautrat          0
# 37698  37698        Injabie3          1
# 37699  37699   caseycavanagh          0
#
# [37700 rows x 3 columns]

# %%
permuted_edges = edges.copy()

# %%
permuted_edges
# Out:
#          id_1   id_2
# 0           0  23977
# 1           1  34526
# 2           1   2370
# 3           1  14683
# 4           1  29982
# ...       ...    ...
# 288998  37527  37596
# 288999  37529  37601
# 289000  37644   2347
# 289001  25879   2347
# 289002  25616   2347
#
# [289003 rows x 2 columns]
